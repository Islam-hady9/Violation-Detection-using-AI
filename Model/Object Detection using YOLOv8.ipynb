# %%
# For video
from ultralytics import YOLO

# Load a pr-trained model
model = YOLO("yolov8n.pt")

# Use the model to detect object
model.predict(source=r"Test videos\Test video_1.mp4", show=True)
# Out:
# WARNING  inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (1/307) f:\Violation Detection Project\Violation-Detection-using-AI\Model\Test videos\Test video_1.mp4: 384x640 10 cars, 1 bus, 3 trucks, 233.3ms
# video 1/1 (2/307) f:\Violation Detection Project\Violation-Detection-using-AI\Model\Test videos\Test video_1.mp4: 384x640 12 cars, 2 trucks, 272.1ms
# ...
